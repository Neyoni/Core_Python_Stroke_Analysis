# %% [markdown]
# # Cardiovascular Neurology
# ## Stroke Analytics Application
#
# Welcome to the Stroke Analytics Application.
# This program allows users to interactively explore different stroke-related analytics, which include
#
# - Smoking and Hypertension analysis
# - Heart Disease and Stroke relationships
# - Gender-based Stroke occurrences
# - Dietary Habits and Stroke Trends
# - Sleep hours analysis, etc.
#
# The system is designed to:
# - Load the stroke dataset.
# - Provide user-friendly menu options.
# - Display results.
# - Saves results as a CSV file.
#
# ---
#
# **Please follow all instructions:**
# - Follow the prompts.
# - Select your desired analysis option.
# - You can check various analyses or exit anytime.
#
# ---

# %%
# Importing the created modules
from dataset_module import load_dataset #Responsible for loading the dataset
from query_module import QueryModule, save_to_csv, save_records_to_csv #Contains the Query module class and saves analytics result to csv
from ui_module import user_interface #Responsible for user interaction.


# Main function
def main():
    print("Welcome to the Stroke Analytics Application\n")
    print("This program allows you analyze various features and their relation to stroke.\n")
    user_interface()

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Welcome to the Stroke Analytics Application
#
# This program allows you analyze various features and their relation to stroke.
# Please input your name:  h
# Welcome h to the Stroke Analytics Application
#
#           Please find below the various options for the subgroup analytics.
#
#           A Smokers with Hypertension resulting in stroke.
#
#           B Heart diseases that leads to stroke.
#
#           C Hypertension resulting in stroke and those not resulting in stroke based on genders.
#
#           D Smoking habits that resulted in stroke an smoking habits that did not result in stroke.
#
#           E Areas and their resulting stroke analysis.
#
#           F Stroke and Dietary analysis.
#
#           G Hypertension resulting in stroke.
#
#           H Details of people whose hypertension did and did not result in stroke.
#
#           I Details of people whose heart dieases resulted in stroke.
#
#           J Descriptive statistics of each features.
#
# ...
